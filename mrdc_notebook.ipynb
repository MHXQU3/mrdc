# %%
from sqlalchemy import create_engine, inspect
import numpy as np
import pandas as pd
import yaml 
import psycopg2

# %%
path = r'C:\Users\Razer\Documents\AI_Core\mrdc\db_creds.yaml'

# %%
with open(path, 'r') as file:
    db_creds = yaml.safe_load(file)
print(db_creds)
# Out:
# {'RDS_HOST': 'data-handling-project-readonly.cq2e8zno855e.eu-west-1.rds.amazonaws.com', 'RDS_PASSWORD': 'AiCore2022', 'RDS_USER': 'aicore_admin', 'RDS_DATABASE': 'postgres', 'RDS_PORT': 5432, 'RDS_DATABASE_TYPE': 'postgresql', 'DBAPI': 'psycopg2', 'LOCAL_DATABASE_TYPE': 'postgresql', 'LOCAL_DB_API': 'psycopg2', 'LOCAL_USER': 'postgres', 'LOCAL_PASSWORD': 'password', 'LOCAL_HOST': 'localhost', 'LOCAL_PORT': 5432, 'LOCAL_DATABASE': 'sales_data'}

# %%
HOST = db_creds.get('RDS_HOST')
PASSWORD = db_creds.get('RDS_PASSWORD')
USER = db_creds.get('RDS_USER')
DATABASE = db_creds.get('RDS_DATABASE')
PORT = db_creds.get('RDS_PORT')
DBTYPE = db_creds.get('RDS_DATABASE_TYPE')
DBAPI = db_creds.get('DBAPI')

# %%
url = f"{DBTYPE}+{DBAPI}://{USER}:{PASSWORD}@{HOST}:{PORT}/{DATABASE}"
url
# Out:
# 'postgresql+psycopg2://aicore_admin:AiCore2022@data-handling-project-readonly.cq2e8zno855e.eu-west-1.rds.amazonaws.com:5432/postgres'

# %%
engine = create_engine(url)
print(engine)
# Out:
# Engine(postgresql+psycopg2://aicore_admin:***@data-handling-project-readonly.cq2e8zno855e.eu-west-1.rds.amazonaws.com:5432/postgres)

# %%
engine.connect()
inspector = inspect(engine)
table_names = inspector.get_table_names()
print(table_names)
# Out:
# ['legacy_store_details', 'dim_card_details', 'legacy_users', 'orders_table']

# %%
'''
AICore notebook 
from sqlalchemy import inspect
inspector = inspect(engine)
inspector.get_table_names()

actors = pd.read_sql_table('actor', engine)
'''
# Out:
# "\nAICore notebook \nfrom sqlalchemy import inspect\ninspector = inspect(engine)\ninspector.get_table_names()\n\nactors = pd.read_sql_table('actor', engine)\n"

# %%
# from sqlalchemy import text
# with engine.connect() as connection:
#     result = connection.execute(text("SELECT * FROM legacy_users"))
#     for row in result:
#         print(row)

# %%
users = pd.read_sql_table('legacy_users', engine)
users
# Out:
#        index first_name last_name date_of_birth                       company  \
# 0          0   Sigfried     Noack    1990-09-30            Heydrich Junitz KG
# 1          1        Guy     Allen    1940-12-01                       Fox Ltd
# 2          2      Harry  Lawrence    1995-08-02     Johnson, Jones and Harris
# 3          3     Darren   Hussain    1972-09-23                   Wheeler LLC
# 4          4      Garry     Stone    1952-12-20                    Warner Inc
# ...      ...        ...       ...           ...                           ...
# 15315  14913    Stephen   Jenkins    1943-08-09  Thornton, Carroll and Newman
# 15316  14994    Stephen     Smith    1948-08-20               Robinson-Harris
# 15317  15012    Stephen  Losekann    1940-10-09                       Rosenow
# 15318  15269    Stephen    Rivera    1952-06-04         Taylor, Fry and Jones
# 15319   1249    Stephen    Duncan    1994-03-27    Phillips, Brown and Powell
#
# ...

# %%
users_rd = users.drop_duplicates()
users_rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15320 entries, 0 to 15319
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          15320 non-null  int64
#  1   first_name     15320 non-null  object
#  2   last_name      15320 non-null  object
#  3   date_of_birth  15320 non-null  object
#  4   company        15320 non-null  object
#  5   email_address  15320 non-null  object
#  6   address        15320 non-null  object
#  7   country        15320 non-null  object
#  8   country_code   15320 non-null  object
#  9   phone_number   15320 non-null  object
#  10  join_date      15320 non-null  object
#  11  user_uuid      15320 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 1.4+ MB

# %%
def convert_birth_date(users_rd):
    # Apply the conversion logic directly to the 'birth_date' column
    try:
        users_rd['join_date'] = pd.to_datetime(users_rd['join_date'], errors='coerce').dt.strftime('%Y-%m-%d')
    except ValueError:
        users_rd['join_date'] = users_rd['join_date'].apply(lambda x: pd.to_datetime(x, format='%Y %B %d').strftime('%Y-%m-%d'))
    
    return users_rd

# %%
users_rd = convert_birth_date(users_rd)

# Print the entry at index 202
print(users_rd['join_date'].iloc[202])
# Out:
# nan

# %%
users_rd = convert_birth_date(users_rd)

# Display the DataFrame to verify the results
print(users_rd)
# Out:
#        index first_name last_name date_of_birth                       company  \
# 0          0   Sigfried     Noack    1990-09-30            Heydrich Junitz KG
# 1          1        Guy     Allen    1940-12-01                       Fox Ltd
# 2          2      Harry  Lawrence    1995-08-02     Johnson, Jones and Harris
# 3          3     Darren   Hussain    1972-09-23                   Wheeler LLC
# 4          4      Garry     Stone    1952-12-20                    Warner Inc
# ...      ...        ...       ...           ...                           ...
# 15315  14913    Stephen   Jenkins    1943-08-09  Thornton, Carroll and Newman
# 15316  14994    Stephen     Smith    1948-08-20               Robinson-Harris
# 15317  15012    Stephen  Losekann    1940-10-09                       Rosenow
# 15318  15269    Stephen    Rivera    1952-06-04         Taylor, Fry and Jones
# 15319   1249    Stephen    Duncan    1994-03-27    Phillips, Brown and Powell
#
# ...

# %%
row202 = users_rd.iloc[202]
row202
# Out:
# index                                               202
# first_name                                      Mohamed
# last_name                                      Woodward
# date_of_birth                                1968-10-25
# company                        Barrett, Jones and Smith
# email_address               colemandanny@grant-lamb.org
# address          96 Danny trail\nEast Valerie\nKA39 2JN
# country                                  United Kingdom
# country_code                                         GB
# phone_number                              (0113)4960884
# join_date                                           NaN
# user_uuid          6904f151-6d32-4d1e-b477-41801a9a8e83
# Name: 202, dtype: object

# %%
# Filter out rows where 'birth_date' is NaN or null
users_rd_cleaned = users_rd.dropna(subset=['join_date'])

# %%
def convert_birth_date(users_rd):
    def convert_single_date(date_str):
        try:
            # Attempt standard 'YYYY-MM-DD' format conversion
            return pd.to_datetime(date_str).strftime('%Y-%m-%d')
        except ValueError:
            try:
                # Attempt 'YYYY MONTH DD' format conversion
                return pd.to_datetime(date_str, format='%Y %B %d').strftime('%Y-%m-%d')
            except ValueError:
                # Return the original value if all parsing attempts fail
                return pd.NaT

    # Apply the conversion function to the 'birth_date' column
    users_rd['join_date'] = users_rd['join_date'].apply(convert_single_date)
    
    return users_rd

# Apply the function to your DataFrame
users_rd = convert_birth_date(users_rd)

# Print the entry at index 202
print(f"Entry at index 202: {users_rd['join_date'].iloc[202]}")
# Out:
# Entry at index 202: NaT

# %%
# Apply the conversion function to the cleaned DataFrame
users_rd_cleaned = convert_birth_date(users_rd_cleaned)
# Out:
# C:\Users\Razer\AppData\Local\Temp\ipykernel_21980\3640901061.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   users_rd['join_date'] = users_rd['join_date'].apply(convert_single_date)

# %%
import re
# Check for NaT/NaN entries after conversion
nan_entries = users_rd_cleaned[users_rd_cleaned['join_date'].isna()]
print(f"Number of NaT/NaN entries after conversion: {len(nan_entries)}")
display(nan_entries)

# Check for invalid format entries after conversion
invalid_entries = users_rd_cleaned[~users_rd_cleaned['join_date'].apply(lambda x: bool(re.match(r'^\d{4}-\d{2}-\d{2}$', str(x))))]
print(f"Number of invalid format entries after conversion: {len(invalid_entries)}")
display(invalid_entries)
# Out:
# Number of NaT/NaN entries after conversion: 0
# Empty DataFrame
# Columns: [index, first_name, last_name, date_of_birth, company, email_address, address, country, country_code, phone_number, join_date, user_uuid]
# Index: []
# Number of invalid format entries after conversion: 0
# Empty DataFrame
# Columns: [index, first_name, last_name, date_of_birth, company, email_address, address, country, country_code, phone_number, join_date, user_uuid]
# Index: []

# %%
# Check for any NaT (Not a Time) values in the column
nan_entries = users_rd[users_rd['join_date'].isna()]

print(f"Number of NaT/NaN entries: {len(nan_entries)}")
display(nan_entries)
# Out:
# Number of NaT/NaN entries: 59
#        index  first_name     last_name date_of_birth  \
# 202      202     Mohamed      Woodward    1968-10-25
# 752      752  PYCLKLLC7I    W350SCUD6R    KBTI7FI7Y3
# 866      867        NULL          NULL          NULL
# 1022    1023        NULL          NULL          NULL
# 1046    1047  GI4C78KWH0    UTB5PPYFG8    OFH8YGZJWN
# 1073    1074    Michelle         Young    1963-08-10
# 1347    1349    Jonathan       Johnson    1952-12-03
# 1569    1571       Mandy        Little    1990-07-23
# 1805    1807        NULL          NULL          NULL
# 2103    2103        NULL          NULL          NULL
# 2437    2439        NULL          NULL          NULL
# 2439    2441    Johannes      Mitschke    2003-06-04
# 2480    2482      Ashley         Kelly    1941-11-27
# 2739    6526        NULL          NULL          NULL
# 2764    2764        NULL          NULL          NULL
# 2995    2997  DPAJNJL6PR    B8ZGN8ZJ84    PQPEUO937L
# ...

# %%
a = users_rd.iloc[752]
a
# Out:
# index                   752
# first_name       PYCLKLLC7I
# last_name        W350SCUD6R
# date_of_birth    KBTI7FI7Y3
# company          R7IZUNSQX0
# email_address    3Q791B3VIY
# address          YW2YXLOQ5J
# country          I7G4DMDZOZ
# country_code     VSM4IZ4EL3
# phone_number     A4Q4HQBI3I
# join_date               NaT
# user_uuid        W43MSCMQ88
# Name: 752, dtype: object

# %%
b = users_rd.iloc[751]
b
# Out:
# index                                                          751
# first_name                                                Terrence
# last_name                                                    Moyer
# date_of_birth                                           1999-08-21
# company                                                Douglas LLC
# email_address                            hmartin@campbell-horn.com
# address          9516 Martinez Parkways Suite 850\nWest Victor,...
# country                                              United States
# country_code                                                    US
# phone_number                                      076.583.0124x510
# join_date                                               2019-07-19
# user_uuid                     9c9412e3-78c0-47c0-83f2-635414a2230a
# Name: 751, dtype: object

# %%
users_rd.replace('NULL', np.nan, inplace=True)

# %%
users_rd.dropna(subset=['date_of_birth', 'email_address', 'user_uuid'], how='any', axis=0, inplace=True)

# %%
# Check for any NaT (Not a Time) values in the column
nan_entries = users_rd[users_rd['join_date'].isna()]

print(f"Number of NaT/NaN entries: {len(nan_entries)}")
display(nan_entries)
# Out:
# Number of NaT/NaN entries: 38
#        index  first_name     last_name date_of_birth  \
# 202      202     Mohamed      Woodward    1968-10-25
# 752      752  PYCLKLLC7I    W350SCUD6R    KBTI7FI7Y3
# 1046    1047  GI4C78KWH0    UTB5PPYFG8    OFH8YGZJWN
# 1073    1074    Michelle         Young    1963-08-10
# 1347    1349    Jonathan       Johnson    1952-12-03
# 1569    1571       Mandy        Little    1990-07-23
# 2439    2441    Johannes      Mitschke    2003-06-04
# 2480    2482      Ashley         Kelly    1941-11-27
# 2995    2997  DPAJNJL6PR    B8ZGN8ZJ84    PQPEUO937L
# 3164    3167     Barbara       Daniels    1960-10-30
# 3536    3539  E5139W1FJ3    X88YLZX0JX    7KGJ3C5TSW
# 4162    4165      Mathew         Clark    1991-11-20
# 4357    4360       Sarah        Hughes    1955-03-25
# 5306    5309  XKDVQD7BH2    4YSEX8AY1Z    RQTF5XSXP4
# 5553    5557         Roy   Grein Groth    1940-05-25
# 6134    6138        Brit        Köster    1984-04-03
# ...

# %%
users_rd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15299 entries, 0 to 15319
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          15299 non-null  int64
#  1   first_name     15299 non-null  object
#  2   last_name      15299 non-null  object
#  3   date_of_birth  15299 non-null  object
#  4   company        15299 non-null  object
#  5   email_address  15299 non-null  object
#  6   address        15299 non-null  object
#  7   country        15299 non-null  object
#  8   country_code   15299 non-null  object
#  9   phone_number   15299 non-null  object
#  10  join_date      15261 non-null  object
#  11  user_uuid      15299 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 1.5+ MB

# %%
import tabula as tb
link = "card_details.pdf"
pdf_data = tb.read_pdf(link, pages='all')
pdf_data = pd.concat(pdf_data, ignore_index=True)
pdf_data = pdf_data.dropna(axis=1, how = 'all')
pdf_df = pdf_data.reset_index(drop=True)
print(pdf_df.head())
# Out:
#         card_number expiry_date                card_provider  \
# 0    30060773296197       09/26  Diners Club / Carte Blanche
# 1   349624180933183       10/23             American Express
# 2  3529023891650490       06/23                 JCB 16 digit
# 3   213142929492281       09/27                 JCB 15 digit
# 4      502067329974       10/25                      Maestro
#
#   date_payment_confirmed
# 0             2015-11-25
# 1             2001-06-18
# 2             2000-12-26
# 3             2011-02-12
# 4             1997-03-13

# %%
import tabula as tb
import pandas as pd

# Read the PDF with parameters that might help
link = "card_details.pdf"
pdf_data = tb.read_pdf(link, pages='all', multiple_tables=True, lattice=True)

# If pdf_data is a list of DataFrames, concatenate them
if isinstance(pdf_data, list):
    pdf_data = pd.concat(pdf_data, ignore_index=True)

# Display the raw DataFrame to understand its structure
print(pdf_data.head())

# Optionally clean up unwanted characters
pdf_data = pdf_data.replace({'\\': ''}, regex=True)

# Assume the structure is: card_number, expiry_date, card_provider, and date_payment_confirmed
# Handle cases where 'date_payment_confirmed' appears on a new line

# This assumes that 'date_payment_confirmed' is only in the last row of a misaligned entry
# Rebuild DataFrame from potentially misaligned entries
fixed_data = []

# Iterate through rows to fix alignment
for i in range(0, len(pdf_data), 1):
    row = pdf_data.iloc[i]
    if pd.isna(row['date_payment_confirmed']):
        # Append to the current row if date_payment_confirmed is missing
        if fixed_data:
            fixed_data[-1]['date_payment_confirmed'] = row['card_provider']
        fixed_data.append(row.to_dict())
    else:
        fixed_data.append(row.to_dict())

# Convert list of dicts to DataFrame
fixed_df = pd.DataFrame(fixed_data)

# Drop columns that are entirely NaN
fixed_df = fixed_df.dropna(axis=1, how='all')

# Reset index to clean up DataFrame
fixed_df = fixed_df.reset_index(drop=True)

# Display the cleaned DataFrame
print(fixed_df.head())
# Out:
#         card_number expiry_date                card_provider  \
# 0    30060773296197       09/26  Diners Club / Carte Blanche
# 1   349624180933183       10/23             American Express
# 2  3529023891650490       06/23                 JCB 16 digit
# 3   213142929492281       09/27                 JCB 15 digit
# 4      502067329974       10/25                      Maestro
#
#   date_payment_confirmed
# 0             2015-11-25
# 1             2001-06-18
# 2             2000-12-26
# 3             2011-02-12
# 4             1997-03-13
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[32], line 16
#      13 print(pdf_data.head())
#      15 # Optionally clean up unwanted characters
# ---> 16 pdf_data = pdf_data.replace({'\\': ''}, regex=True)
#      18 # Assume the structure is: card_number, expiry_date, card_provider, and date_payment_confirmed
# ...
